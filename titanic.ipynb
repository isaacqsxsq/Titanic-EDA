# %%
import pandas as pd
train = pd.read_csv('datasets/titanic/train.csv')
test = pd.read_csv('datasets/titanic/test.csv')

train = train.set_index('PassengerId')
test = test.set_index('PassengerId')

# %%
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
test.head()
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#               Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# PassengerId
# 892          34.5      0      0   330911   7.8292   NaN        Q
# 893          47.0      1      0   363272   7.0000   NaN        S
# 894          62.0      0      0   240276   9.6875   NaN        Q
# 895          27.0      0      0   315154   8.6625   NaN        S
# 896          22.0      1      1  3101298  12.2875   NaN        S

# %%
train.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699113    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526507    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.416700    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
train.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
train.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name            str
# Sex             str
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket          str
# Fare        float64
# Cabin           str
# Embarked        str
# dtype: object

# %%
train.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
print(train['Survived'].unique())
print(train['Pclass'].unique())
print(train['Sex'].unique())
print(train['Embarked'].unique())
# Out:
# [0 1]
# [3 1 2]
# <StringArray>
# ['male', 'female']
# Length: 2, dtype: str
# <StringArray>
# ['S', 'C', 'Q', nan]
# Length: 4, dtype: str

# %% [markdown]
# Survived: 0 for dead and 1 for survived
# Pclass: 1,2,3 classes / onehot encoding
# Name: drop
# Sex: 'male' and 'female' onehot encoding
# Age: 177 missing value / impute median
# SibSp: num of siblings or spouse
# Parch: num of parents or children
# Ticket: drop
# Fare: cost
# Cabin: drop (too many missing value)
# Embarked: 2 missing value / S,C, and Q / impute most frequent

# %%
train = train.drop(columns= ['Name', 'Ticket', 'Cabin'])
test = test.drop(columns=['Name', 'Ticket', 'Cabin'])

# %%
train.head()
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# PassengerId
# 1                   0       3    male  22.0      1      0   7.2500        S
# 2                   1       1  female  38.0      1      0  71.2833        C
# 3                   1       3  female  26.0      0      0   7.9250        S
# 4                   1       1  female  35.0      1      0  53.1000        S
# 5                   0       3    male  35.0      0      0   8.0500        S

# %%
test.head()
# Out:
#              Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# PassengerId
# 892               3    male  34.5      0      0   7.8292        Q
# 893               3  female  47.0      1      0   7.0000        S
# 894               2    male  62.0      0      0   9.6875        Q
# 895               3    male  27.0      0      0   8.6625        S
# 896               3  female  22.0      1      1  12.2875        S

# %%
X = train.drop('Survived', axis=1)
y = train['Survived']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    random_state=42,
    stratify=train['Survived']
)

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

num_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ("scaler", StandardScaler())
])
cat_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ohe', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

ct = ColumnTransformer([
    ('num', num_transformer, ['Age','SibSp','Parch','Fare']),
    ('cat', cat_transformer, ['Embarked', 'Sex', 'Pclass']),
])

# %%
X_train_pro.head()
# Out:
#              num__Age  num__SibSp  num__Parch  num__Fare  cat__Embarked_C  \
# PassengerId
# 487          0.405333    0.536677   -0.451483   1.240397              0.0
# 239         -0.829763   -0.464720   -0.451483  -0.436028              0.0
# 723          0.328140   -0.464720   -0.451483  -0.383310              0.0
# 185         -1.987666   -0.464720    1.951631  -0.192999              0.0
# 57          -0.675376   -0.464720   -0.451483  -0.436028              0.0
#
#              cat__Embarked_Q  cat__Embarked_S  cat__Sex_female  cat__Sex_male  \
# PassengerId
# 487                      0.0              1.0              1.0            0.0
# 239                      0.0              1.0              0.0            1.0
# 723                      0.0              1.0              0.0            1.0
# 185                      0.0              1.0              1.0            0.0
# 57                       0.0              1.0              1.0            0.0
#
# ...

# %% [markdown]
# ## Select Model
# 1. Logistic Regression
# 2. Random Forest
# 3. SVC

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
full_pipeline_log = Pipeline([
    ('preprocessor', ct),
    ('model', LogisticRegression(random_state=42))
])

scores_log = cross_val_score(full_pipeline_log, X, y, cv=5)

# %%
scores_log.mean()
# Out:
# np.float64(0.7901387232439896)

# %%
from sklearn.ensemble import RandomForestClassifier
full_pipeline_random = Pipeline([
    ('preprocessor', ct),
    ('model', RandomForestClassifier(random_state=42))
])

scores_random = cross_val_score(full_pipeline_random, X, y, cv=5)

# %%
scores_random.mean()
# Out:
# np.float64(0.8058565061829139)

# %%
from sklearn.svm import SVC
full_pipeline_SVC = Pipeline([
    ('preprocessor', ct),
    ('model', SVC())
])

scores_SVC= cross_val_score(full_pipeline_SVC, X, y, cv=5)

# %%
scores_SVC.mean()
# Out:
# np.float64(0.8271608813006089)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 4))
plt.plot([1]*5, scores_SVC, ".")
plt.plot([2]*5, scores_random, ".")
plt.plot([3]*5, scores_log, ".")
plt.boxplot([scores_SVC, scores_random, scores_log], labels=("SVM", "Random Forest", "Log"))
plt.ylabel("Accuracy")
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_22216\174615433.py:6: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([scores_SVC, scores_random, scores_log], labels=("SVM", "Random Forest", "Log"))

# %%
from sklearn.model_selection import GridSearchCV
grid = {
    'model__C': [0.1, 1, 10, 100],
    'model__gamma': ['scale', 'auto', 0.01, 0.001],
    'model__kernel': ['rbf', 'linear']
}
grid_search = GridSearchCV(full_pipeline_SVC, grid, cv=5, scoring='accuracy', n_jobs=-1)

# %%
grid_search.fit(X, y)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['Age',
#                                                                           'SibSp',
#                                                                           'Parch',
#                                                                           'Fare']),
# ...

# %%
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'model__C': 1, 'model__gamma': 'auto', 'model__kernel': 'rbf'}
# 0.828278199736363

# %%
final_pipeline = Pipeline([
    ('preprocessor', ct),
    ('model', SVC(**{k.replace('model__', ''): v for k, v in grid_search.best_params_.items()}))
])

# %%
final_pipeline.fit(X,y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Age', 'SibSp', 'Parch',
#                                                    'Fare']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
# ...

# %%
prediction = final_pipeline.predict(test)

# %%
submission = pd.DataFrame({
    'PassengerId': test.index,
    'Survived': prediction
})

submission.to_csv('submission.csv', index=False)
